# %% [markdown]
# ### Groupby-Lab-Solutions

# %% [markdown]
# **1).** Load in the users dataset

# %%
# Your Code Here
import pandas as pd
df = pd.read_csv(r'../../data/user.tbl', sep='|')

# %% [markdown]
# **2).** For each occupation in "users", count the number of occurrences.

# %%
# Your Code Here
df.groupby('occupation')['occupation'].count()
# Out:
# occupation
# administrator     79
# artist            28
# doctor             7
# educator          95
# engineer          67
# entertainment     18
# executive         32
# healthcare        16
# homemaker          7
# lawyer            12
# librarian         51
# marketing         26
# none               9
# other            105
# programmer        66
# retired           14
# salesman          12
# scientist         31
# student          196
# technician        27
# writer            45
# Name: occupation, dtype: int64

# %% [markdown]
# **3).** For each occupation, calculate the mean age.

# %%
# Your Code Here
df.groupby('occupation')['age'].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# **4).** For each occupation, calculate the minimum and maximum ages.

# %%
# Your Code Here
df.groupby('occupation')['age'].agg(['min', 'max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# **5).** For each combination of occupation and gender, calculate the mean age.

# %%
# Your Code Here
df.groupby(['occupation', 'gender'])['age'].mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
#                M         34.028986
# programmer     F         32.166667
#                M         33.216667
# retired        F         70.000000
#                M         62.538462
# salesman       F         27.000000
#                M         38.555556
# scientist      F         28.333333
#                M         36.321429
# student        F         20.750000
#                M         22.669118
# technician     F         38.000000
#                M         32.961538
# writer         F         37.631579
#                M         35.346154
# Name: age, dtype: float64

# %% [markdown]
# **6).** Find the female with the highest age in each occupation.

# %%
df[df.gender == 'F'].groupby('occupation')['age'].idxmax().values
# Out:
# array([265, 122,  64, 785, 838,  97, 169, 721, 443, 753, 808, 417, 809,
#        420, 859, 456, 729, 860, 937, 557], dtype=int64)

# %%
df.iloc[oldest_women]
# Out:
#      user_id  age gender     occupation zip_code
# 265      266   62      F  administrator    78756
# 122      123   48      F         artist    20008
# 64        65   51      F       educator    48118
# 785      786   36      F       engineer    01754
# 838      839   38      F  entertainment    90814
# 97        98   49      F      executive    90291
# 169      170   53      F     healthcare    30067
# 721      722   50      F      homemaker    17331
# 443      444   51      F         lawyer    53202
# 753      754   59      F      librarian    62901
# 808      809   50      F      marketing    30803
# 417      418   55      F           none    21206
# 809      810   55      F          other    80526
# 420      421   38      F     programmer    55105
# 859      860   70      F        retired    48322
# 456      457   33      F       salesman    30011
# 729      730   31      F      scientist    32114
# 860      861   38      F        student    14085
# 937      938   38      F     technician    55038
# 557      558   56      F         writer    63132

# %%
df = df.drop[df != 0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-6c9d3dda2f2f> in <module>
# ----> 1 df = df.drop[df != 0]
#
# TypeError: 'method' object is not subscriptable

# %%
df = pd.read_csv(r'https://raw.githubusercontent.com/JonathanBechtel/data/master/boston.csv')

# %%
~(df == 0).any(1)
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9       True
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
#        ...
# 476     True
# 477     True
# 478     True
# 479     True
# 480     True
# 481     True
# 482     True
# 483     True
# 484     True
# 485     True
# 486     True
# 487     True
# 488     True
# 489     True
# 490     True
# 491     True
# 492     True
# 493     True
# 494     True
# 495     True
# 496     True
# 497     True
# 498     True
# 499     True
# 500     True
# 501     True
# 502     True
# 503     True
# 504     True
# 505     True
# Length: 506, dtype: bool
