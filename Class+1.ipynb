# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# load in crime data 
df = pd.read_csv('/Users/CSSBU/Desktop/NYC_crime.csv')
df.drop(df.columns[0], axis=1, inplace=True)
df.head(10)
# Out:
#   CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM      RPT_DT  KY_CD  \
# 0   01/01/2016     00:01:00   12/31/2017     23:59:00  01/02/2019    233
# 1   01/01/2016     12:00:00   03/01/2016     12:00:00  03/11/2019    578
# 2   02/03/2016     20:40:00   02/03/2019     20:50:00  02/03/2019    344
# 3   02/20/2016     00:00:00   08/08/2018     00:00:00  02/20/2019    233
# 4   02/25/2016     20:11:00   02/25/2019     20:29:00  02/25/2019    361
# 5   03/05/2016     00:00:00   03/04/2019     23:35:00  03/05/2019    112
# 6   03/06/2016     08:00:00   03/06/2016     09:00:00  03/06/2019    116
# 7   03/18/2016     13:40:00   03/12/2019     13:46:00  03/18/2019    126
# 8   03/23/2016     00:01:00   03/23/2017     00:01:00  03/23/2019    233
# 9   03/24/2016     20:00:00   03/25/2016     08:00:00  03/26/2019    341
#
#                        OFNS_DESC  PD_CD                         PD_DESC  \
# 0                     SEX CRIMES    175                SEXUAL ABUSE 3,2
# ...

# %%
df.describe()
# Out:
#             KY_CD       PD_CD  ADDR_PCT_CD  PARKS_NM    X_COORD_CD  \
# count   26.000000   26.000000    26.000000       0.0  2.600000e+01
# mean   221.461538  416.884615    20.846154       NaN  9.941682e+05
# std    123.405099  270.845392    11.705357       NaN  7.643319e+03
# min    104.000000  101.000000     1.000000       NaN  9.819260e+05
# 25%    112.000000  175.000000     9.250000       NaN  9.860040e+05
# 50%    233.000000  329.500000    25.500000       NaN  9.970630e+05
# 75%    340.000000  715.500000    31.500000       NaN  9.996850e+05
# max    578.000000  847.000000    34.000000       NaN  1.003411e+06
#
#           Y_COORD_CD   Latitude  Longitude
# count      26.000000  26.000000  26.000000
# mean   225042.269231  40.784365 -73.964169
# std     17684.173932   0.048532   0.027616
# min    196411.000000  40.705787 -74.008384
# 25%    208816.500000  40.739838 -73.993674
# 50%    231052.500000  40.800859 -73.953731
# 75%    236472.000000  40.815732 -73.944231
# ...
