# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
drinks = pd.read_csv('/Users/CSSBU/Desktop/drinks.csv')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
print(drinks.columns)
# Out:
# Index([u'country', u'beer_servings', u'spirit_servings', u'wine_servings',
#        u'total_litres_of_pure_alcohol', u'continent'],
#       dtype='object')

# %%
#to rename using rename() function: dictionary type 
drink_cols = ['country' , 'beer' , 'spirit' ,'wine' , 'total', 'continent']
drinks = pd.read_csv('/Users/CSSBU/Desktop/drinks.csv', header=0, names= drink_cols)

# %%
#removing columns
# to drop a row:
drinks.drop('total', axis=1)
# Out:
#                   country  beer  spirit  wine continent
# 0             Afghanistan     0       0     0        AS
# 1                 Albania    89     132    54        EU
# 2                 Algeria    25       0    14        AF
# 3                 Andorra   245     138   312        EU
# 4                  Angola   217      57    45        AF
# 5       Antigua & Barbuda   102     128    45       NaN
# 6               Argentina   193      25   221        SA
# 7                 Armenia    21     179    11        EU
# 8               Australia   261      72   212        OC
# 9                 Austria   279      75   191        EU
# 10             Azerbaijan    21      46     5        EU
# 11                Bahamas   122     176    51       NaN
# 12                Bahrain    42      63     7        AS
# 13             Bangladesh     0       0     0        AS
# 14               Barbados   143     173    36       NaN
# 15                Belarus   142     373    42        EU
# ...

# %%
drinks.continent.value_counts(dropna=False)
# Out:
# AF     53
# EU     45
# AS     44
# NaN    23
# OC     16
# SA     12
# Name: continent, dtype: int64

# %%
drinks[drinks.continent.notnull()].head()
# Out:
#        country  beer  spirit  wine  total continent
# 0  Afghanistan     0       0     0    0.0        AS
# 1      Albania    89     132    54    4.9        EU
# 2      Algeria    25       0    14    0.7        AF
# 3      Andorra   245     138   312   12.4        EU
# 4       Angola   217      57    45    5.9        AF

# %%
print(drinks.isnull().sum())
drinks.isnull().plot(kind='bar');
plt.title('Number of null values per column');
# Out:
# country       0
# beer          0
# spirit        0
# wine          0
# total         0
# continent    23
# dtype: int64

# %%
drinks.continent.fillna(value='NA', inplace=True)

# %%
drinks.groupby('continent').beer.describe()
# Out:
#            count        mean        std   min     25%    50%     75%    max
# continent
# AF          53.0   61.471698  80.557816   0.0   15.00   32.0   76.00  376.0
# AS          44.0   37.045455  49.469725   0.0    4.25   17.5   60.50  247.0
# EU          45.0  193.777778  99.631569   0.0  127.00  219.0  270.00  361.0
# NA          23.0  145.434783  79.621163   1.0   80.00  143.0  198.00  285.0
# OC          16.0   89.687500  96.641412   0.0   21.00   52.5  125.75  306.0
# SA          12.0  175.083333  65.242845  93.0  129.50  162.5  198.00  333.0
